# %% [markdown]
# <a href="https://colab.research.google.com/github/Malainine-tech/Python/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Define the path to your file in Google Drive
file_path = "/content/drive/My Drive/Finalproject/AIRBNB.xlsx"  # Update this if your file is in a subfolder

# Load the Excel file
xls = pd.ExcelFile(file_path)

# Display sheet names
print(xls.sheet_names)
# Out:
# ['AB_NYC_2019']

# %%
df = pd.read_excel(file_path)

# Show basic info
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48869 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48873 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 26
# host_id                               0
# host_name                            22
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# dtype: object

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    48895.000000       48895.000000                          38843
# mean         7.029962          23.274466  2018-10-04 01:47:23.910099456
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df["name"] = df["name"].fillna("Unknown")
df["host_name"] = df["host_name"].fillna("Unknown")
df["last_review"] = df["last_review"].fillna("No Reviews").astype(str)  # Convert to string first
df["reviews_per_month"] = df["reviews_per_month"].fillna(0)

# %%
df.duplicated().sum()  # Check for duplicate rows
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()  # Should return 0 for all columns
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df["last_review"] = pd.to_datetime(df["last_review"], errors="coerce")

# %%
df["price"] = pd.to_numeric(df["price"], errors="coerce")
df["reviews_per_month"] = pd.to_numeric(df["reviews_per_month"], errors="coerce")

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    48895.000000       48895.000000                          38843
# mean         7.029962          23.274466  2018-10-04 01:47:23.910099456
# ...

# %%
df["price"].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df["minimum_nights"].hist(bins=50)
# Out:
# <Axes: >

# %%
df = df[df["minimum_nights"] <= 30]

# %%
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)
IQR = Q3 - Q1
df = df[(df["price"] >= Q1 - 1.5 * IQR) & (df["price"] <= Q3 + 1.5 * IQR)]

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.523700e+04  4.523700e+04  45237.000000  45237.000000  45237.000000
# mean   1.891640e+07  6.650566e+07     40.728374    -73.950551    119.906316
# min    2.539000e+03  2.571000e+03     40.499790    -74.244420      0.000000
# 25%    9.457917e+06  7.831209e+06     40.689170    -73.981840     65.000000
# 50%    1.954707e+07  3.044568e+07     40.721680    -73.954300    100.000000
# 75%    2.891192e+07  1.056405e+08     40.763290    -73.933990    159.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990    334.000000
# std    1.090685e+07  7.761744e+07      0.055351      0.046617     68.134209
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    45237.000000       45237.000000                          36495
# mean         5.556580          24.138117  2018-10-04 11:22:36.843403264
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.histplot(df["price"], bins=50, kde=True)
plt.xlim(0, 500)  # Focus on reasonable prices
plt.title("Price Distribution of Airbnb Listings")
plt.xlabel("Price ($)")
plt.ylabel("Count")
plt.show()

# %%
df["neighbourhood_group"].value_counts().plot(kind="bar", figsize=(8,5), color="skyblue")
plt.title("Number of Listings by Neighbourhood Group")
plt.xlabel("Neighbourhood Group")
plt.ylabel("Number of Listings")
plt.show()

# %%
df.groupby("neighbourhood")["price"].mean().sort_values(ascending=False).head(10)
# Out:
# neighbourhood
# Willowbrook           249.000000
# Neponsit              237.000000
# Breezy Point          213.333333
# Tribeca               211.679245
# NoHo                  205.290909
# West Village          193.418641
# Flatiron District     187.592593
# Financial District    184.269891
# Greenwich Village     181.495356
# Midtown               181.335702
# Name: price, dtype: float64

# %%
df.nlargest(10, "number_of_reviews")[["name", "neighbourhood", "price", "number_of_reviews"]]
# Out:
#                                                     name    neighbourhood  \
# 11759                            Room near JFK Queen Bed          Jamaica
# 2031                          Great Bedroom in Manhattan           Harlem
# 2030                      Beautiful Bedroom in Manhattan           Harlem
# 2015                        Private Bedroom in Manhattan           Harlem
# 13495                            Room Near JFK Twin Beds          Jamaica
# 10623                  Steps away from Laguardia airport    East Elmhurst
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !  Lower East Side
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE    East Elmhurst
# 4870                  Private brownstone studio Brooklyn       Park Slope
# 471                      LG Private Room/Family Friendly         Bushwick
#
#        price  number_of_reviews
# 11759     47                629
# 2031      49                607
# 2030      49                597
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.boxplot(x=df["room_type"], y=df["price"], palette="Set2")
plt.ylim(0, 500)  # Limit to remove extreme values for better visualization
plt.title("Price Distribution by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Price ($)")
plt.show()
# Out:
# <ipython-input-35-c6d11aa6689d>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["room_type"], y=df["price"], palette="Set2")

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["room_type"], y=df["availability_365"], palette="coolwarm")
plt.title("Availability (Days) by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Availability (Days)")
plt.show()
# Out:
# <ipython-input-36-840274772f74>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["room_type"], y=df["availability_365"], palette="coolwarm")

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["number_of_reviews"], y=df["price"], alpha=0.5)
plt.xlim(0, 500)  # Focus on listings with <500 reviews for clarity
plt.ylim(0, 500)  # Focus on realistic prices
plt.title("Reviews vs Price Relationship")
plt.xlabel("Number of Reviews")
plt.ylabel("Price ($)")
plt.show()

# %%
full_time_rentals = df[df["availability_365"] == 365]["room_type"].value_counts()
print(full_time_rentals)
# Out:
# room_type
# Private room       604
# Entire home/apt    307
# Shared room        125
# Name: count, dtype: int64

# %%
# Convert 'last_review' to datetime if not already
df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')

# Extract month from 'last_review'
df['last_review_month'] = df['last_review'].dt.month

# Plotting the seasonality trend
plt.figure(figsize=(10, 5))
sns.countplot(x='last_review_month', data=df, palette='viridis')
plt.title('Number of Reviews by Month')
plt.xlabel('Month')
plt.ylabel('Number of Reviews')
plt.show()
# Out:
# <ipython-input-39-5894dbb79c7f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')
# <ipython-input-39-5894dbb79c7f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_review_month'] = df['last_review'].dt.month
# <ipython-input-39-5894dbb79c7f>:9: FutureWarning:
#
# ...

# %%
# Create a monthly average price trend
monthly_price_trend = df.resample('M', on='last_review').price.mean()

# Plotting
plt.figure(figsize=(12, 6))
monthly_price_trend.plot(color='coral')
plt.title('Average Monthly Price Trend')
plt.xlabel('Month')
plt.ylabel('Average Price ($)')
plt.show()
# Out:
# <ipython-input-40-33bd35bf8394>:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_price_trend = df.resample('M', on='last_review').price.mean()

# %%
# Listings available 365 days a year by neighborhood
year_round_neighborhoods = df[df['availability_365'] == 365]['neighbourhood_group'].value_counts()

# Visualizing
year_round_neighborhoods.plot(kind='bar', color='teal', figsize=(10, 5))
plt.title('Year-Round Listings by Neighborhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Number of Year-Round Listings')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Selecting relevant numerical columns
corr_matrix = df[["price", "minimum_nights", "number_of_reviews",
                  "reviews_per_month", "calculated_host_listings_count",
                  "availability_365"]].corr()

# Plotting a heatmap of correlations
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Between Price and Other Factors")
plt.show()

# %%
import pandas as pd

# Define the path to your file in Google Drive
file_path = "/content/drive/My Drive/Finalproject/AIRBNB.xlsx"  # Update this if your file is in a subfolder

# Load the Excel file
xls = pd.ExcelFile(file_path)

# Display sheet names
print(xls.sheet_names)
# Out:
# ['AB_NYC_2019']

# %%
import os
print(os.listdir())  # Lists all files in your current directory
# Out:
# ['.config', 'drive', 'sample_data']

# %%
from google.colab import files
uploaded = files.upload()  # This opens a file upload dialog
# Out:
#      <input type="file" id="files-669c51d7-b11d-4b57-aa24-936d77956042" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-669c51d7-b11d-4b57-aa24-936d77956042">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(os.listdir())  # Ensure 'AIRBNB.xlsx' appears in the list
# Out:
# ['.config', 'drive', 'AIRBNB.xlsx', 'sample_data']

# %%
import pandas as pd

# Adjust the path if necessary
file_path = "/content/drive/My Drive/Finalproject/AIRBNB.xlsx"  # If you uploaded it before, it might be here
df = pd.read_excel(file_path, sheet_name="AB_NYC_2019")

print("File loaded successfully!")
# Out:
# File loaded successfully!

# %%
df.to_csv("airbnb_cleaned.csv", index=False)
print("File saved successfully!")
# Out:
# File saved successfully!

# %%
print(df.isnull().sum())
# Out:
# id                                    0
# name                                 26
# host_id                               0
# host_name                            22
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df["name"].fillna("Unknown", inplace=True)
df["host_name"].fillna("Unknown", inplace=True)
# Out:
# <ipython-input-14-e19b25730c3b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["name"].fillna("Unknown", inplace=True)
# <ipython-input-14-e19b25730c3b>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df["last_review"].fillna(pd.NaT, inplace=True)  # Keeps it as a missing date
# Out:
# <ipython-input-15-6cb56b117c54>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["last_review"].fillna(pd.NaT, inplace=True)  # Keeps it as a missing date

# %%
df["reviews_per_month"].fillna(0, inplace=True)
# Out:
# <ipython-input-16-9f76a4c4aa56>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["reviews_per_month"].fillna(0, inplace=True)

# %%
print(df.isnull().sum())  # Should now show 0 for all key fields
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df["last_review"] = pd.to_datetime(df["last_review"], errors="coerce")

# %%
df["last_review"].fillna("No Reviews", inplace=True)
# Out:
# <ipython-input-19-adde83b96d0f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["last_review"].fillna("No Reviews", inplace=True)
# <ipython-input-19-adde83b96d0f>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'No Reviews' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df["last_review"].fillna("No Reviews", inplace=True)

# %%
print(df.isnull().sum())  # Should show 0 missing values
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
import pandas as pd

# 1️⃣ Load the dataset
file_path = "AIRBNB.xlsx"  # Make sure this file is in your working directory
df = pd.read_excel(file_path, sheet_name="AB_NYC_2019")

# 2️⃣ Fix Missing Values
df["name"].fillna("Unknown", inplace=True)  # Replace missing names
df["host_name"].fillna("Unknown", inplace=True)  # Replace missing host names
df["last_review"] = pd.to_datetime(df["last_review"], errors="coerce")  # Convert to datetime (NaT for missing)
df["reviews_per_month"].fillna(0, inplace=True)  # Replace missing reviews per month with 0

# 3️⃣ Remove Outliers (Price & Minimum Nights)
df = df[df["price"].between(10, 1000)]  # Keep only listings with reasonable prices
df = df[df["minimum_nights"] <= 30]  # Remove long-term rental listings

# 4️⃣ Final Check for Missing Values
print("Missing Values After Cleaning:")
print(df.isnull().sum())

# 5️⃣ Save the Cleaned Data for Tableau
df.to_csv("airbnb_cleaned.csv", index=False)
print("✅ Cleaned dataset saved successfully as 'airbnb_cleaned.csv'!")
# Out:
# <ipython-input-21-8f1e825dac35>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["name"].fillna("Unknown", inplace=True)  # Replace missing names
# <ipython-input-21-8f1e825dac35>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
import pandas as pd

# 1️⃣ Load the dataset
file_path = "AIRBNB.xlsx"  # Update if necessary
df = pd.read_excel(file_path, sheet_name="AB_NYC_2019")

# 2️⃣ Fix Missing Values (New Safe Method)
df = df.assign(
    name=df["name"].fillna("Unknown"),
    host_name=df["host_name"].fillna("Unknown"),
    last_review=pd.to_datetime(df["last_review"], errors="coerce"),  # Keeps missing as NaT
    reviews_per_month=df["reviews_per_month"].fillna(0)
)

# 3️⃣ Remove Outliers (Price & Minimum Nights)
df = df[df["price"].between(10, 1000)]  # Keep reasonable prices
df = df[df["minimum_nights"] <= 30]  # Remove long-term rentals

# 4️⃣ Final Check for Missing Values
print("Missing Values After Cleaning:")
print(df.isnull().sum())

# 5️⃣ Save the Cleaned Data for Tableau
df.to_csv("airbnb_cleaned.csv", index=False)
print("✅ Cleaned dataset saved successfully as 'airbnb_cleaned.csv'!")
# Out:
# Missing Values After Cleaning:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9630
# reviews_per_month                    0
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64
# ✅ Cleaned dataset saved successfully as 'airbnb_cleaned.csv'!

# %%
df["last_review"].fillna(pd.to_datetime("2000-01-01"), inplace=True)
# Out:
# <ipython-input-23-3ac11c058aaf>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["last_review"].fillna(pd.to_datetime("2000-01-01"), inplace=True)

# %%
print(df.isnull().sum())  # Confirm no missing values remain

df.to_csv("airbnb_cleaned.csv", index=False)
print("✅ Final cleaned dataset saved as 'airbnb_cleaned.csv'!")
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64
# ✅ Final cleaned dataset saved as 'airbnb_cleaned.csv'!

# %%
from google.colab import files
files.download("airbnb_cleaned.csv")

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.792400e+04  4.792400e+04  47924.000000  47924.000000  47924.000000
# mean   1.903369e+07  6.779160e+07     40.728830    -73.951881    141.314832
# min    2.539000e+03  2.571000e+03     40.499790    -74.244420     10.000000
# 25%    9.485008e+06  7.903629e+06     40.689940    -73.982850     69.000000
# 50%    1.969717e+07  3.103893e+07     40.722870    -73.955515    105.000000
# 75%    2.914639e+07  1.074344e+08     40.763053    -73.935857    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990   1000.000000
# std    1.096919e+07  7.865885e+07      0.054591      0.046301    116.865661
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    47924.000000       47924.000000                          47924
# mean         5.576016          23.540522  2014-12-29 02:07:49.343126528
# ...

# %%
# Reload necessary libraries since execution state was reset
import pandas as pd

# 1️⃣ Reload the dataset to ensure we start fresh
file_path = "/content/drive/My Drive/Finalproject/AIRBNB.xlsx"  # Update if necessary
df = pd.read_excel(file_path, sheet_name="AB_NYC_2019")

# 2️⃣ Drop Duplicates (Ensuring No Duplicate Listings Exist)
df.drop_duplicates(inplace=True)

# 3️⃣ Fix Missing Values (Based on Screenshots)
df["name"] = df["name"].fillna("Unknown")
df["host_name"] = df["host_name"].fillna("Unknown")
df["last_review"] = df["last_review"].fillna("No Reviews").astype(str)  # Convert missing reviews to string
df["reviews_per_month"] = df["reviews_per_month"].fillna(0)

# 4️⃣ Convert Data Types (Ensuring Correct Formats)
df["last_review"] = pd.to_datetime(df["last_review"], errors="coerce")  # Ensure datetime format
df["price"] = pd.to_numeric(df["price"], errors="coerce")  # Ensure numeric format
df["reviews_per_month"] = pd.to_numeric(df["reviews_per_month"], errors="coerce")

# 5️⃣ Remove Outliers (Minimum Nights & Price)
df = df[df["minimum_nights"] <= 30]  # Removing listings with unrealistic long-term stays

# Applying IQR method to remove price outliers (as per screenshots)
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)
IQR = Q3 - Q1
df = df[(df["price"] >= Q1 - 1.5 * IQR) & (df["price"] <= Q3 + 1.5 * IQR)]

# 6️⃣ Verify Cleaned Data Matches Yesterday’s Output
summary_stats = df.describe()

import ace_tools as tools

# Display final dataset summary for validation
tools.display_dataframe_to_user(name="Summary Statistics (After Exact Cleaning)", dataframe=summary_stats)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-d620d890122e> in <cell line: 0>()
#      32 summary_stats = df.describe()
#      33
# ---> 34 import ace_tools as tools
#      35
#      36 # Display final dataset summary for validation
#
# ModuleNotFoundError: No module named 'ace_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import pandas as pd

# 1️⃣ Load the dataset
file_path = "/content/drive/My Drive/Finalproject/AIRBNB.xlsx"  # Ensure this file is in your working directory
df = pd.read_excel(file_path, sheet_name="AB_NYC_2019")

# 2️⃣ Drop Duplicates
df.drop_duplicates(inplace=True)

# 3️⃣ Fix Missing Values
df["name"] = df["name"].fillna("Unknown")
df["host_name"] = df["host_name"].fillna("Unknown")
df["last_review"] = df["last_review"].fillna("No Reviews").astype(str)  # Convert missing reviews to string
df["reviews_per_month"] = df["reviews_per_month"].fillna(0)

# 4️⃣ Convert Data Types
df["last_review"] = pd.to_datetime(df["last_review"], errors="coerce")  # Ensure datetime format
df["price"] = pd.to_numeric(df["price"], errors="coerce")  # Ensure numeric format
df["reviews_per_month"] = pd.to_numeric(df["reviews_per_month"], errors="coerce")

# 5️⃣ Remove Outliers (Minimum Nights & Price)
df = df[df["minimum_nights"] <= 30]  # Removing listings with unrealistic long-term stays

# Applying IQR method to remove price outliers (as per previous cleaning)
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)
IQR = Q3 - Q1
df = df[(df["price"] >= Q1 - 1.5 * IQR) & (df["price"] <= Q3 + 1.5 * IQR)]

# 6️⃣ Verify Cleaned Data Matches Previous Output
pd.options.display.float_format = '{:,.2f}'.format  # Format numbers for readability
print(df.describe())

# 7️⃣ Save the Cleaned Dataset for Tableau
df.to_csv("airbnb_cleaned.csv", index=False)
print("✅ Final cleaned dataset saved successfully as 'airbnb_cleaned.csv'!")
# Out:
#                  id        host_id  latitude  longitude     price  \
# count     45,237.00      45,237.00 45,237.00  45,237.00 45,237.00
# mean  18,916,395.51  66,505,663.83     40.73     -73.95    119.91
# min        2,539.00       2,571.00     40.50     -74.24      0.00
# 25%    9,457,917.00   7,831,209.00     40.69     -73.98     65.00
# 50%   19,547,068.00  30,445,677.00     40.72     -73.95    100.00
# 75%   28,911,924.00 105,640,471.00     40.76     -73.93    159.00
# max   36,487,245.00 274,321,313.00     40.91     -73.71    334.00
# std   10,906,854.26  77,617,442.25      0.06       0.05     68.13
#
#        minimum_nights  number_of_reviews                    last_review  \
# count       45,237.00          45,237.00                          36495
# mean             5.56              24.14  2018-10-04 11:22:36.843403264
# min              1.00               0.00            2011-03-28 00:00:00
# 25%              1.00               1.00            2018-07-07 00:00:00
# ...

# %%
from google.colab import files
files.download("airbnb_cleaned.csv")

# %%
import pandas as pd

# 1️⃣ Load the dataset
file_path = "/content/drive/My Drive/Finalproject/AIRBNB.xlsx"  # Ensure this file is in your working directory
df = pd.read_excel(file_path, sheet_name="AB_NYC_2019")

# 2️⃣ Drop Duplicates
df.drop_duplicates(inplace=True)

# 3️⃣ Fix Missing Values
df["name"] = df["name"].fillna("Unknown")
df["host_name"] = df["host_name"].fillna("Unknown")
df["last_review"] = df["last_review"].fillna("No Reviews").astype(str)  # Convert missing reviews to string
df["reviews_per_month"] = df["reviews_per_month"].fillna(0)

# 4️⃣ Convert Data Types
df["last_review"] = pd.to_datetime(df["last_review"], errors="coerce")  # Ensure datetime format
df["price"] = pd.to_numeric(df["price"], errors="coerce")  # Ensure numeric format
df["reviews_per_month"] = pd.to_numeric(df["reviews_per_month"], errors="coerce")

# 5️⃣ Remove Outliers (Minimum Nights & Price)
df = df[df["minimum_nights"] <= 30]  # Removing listings with unrealistic long-term stays

# Applying IQR method to remove price outliers (as per previous cleaning)
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)
IQR = Q3 - Q1
df = df[(df["price"] >= Q1 - 1.5 * IQR) & (df["price"] <= Q3 + 1.5 * IQR)]

# 6️⃣ Verify Cleaned Data Matches Previous Output
pd.options.display.float_format = '{:,.2f}'.format  # Format numbers for readability
print(df.describe())

# 7️⃣ Save the Cleaned Dataset for Tableau
df.to_csv("airbnb_cleaned.csv", index=False)
print("✅ Final cleaned dataset saved successfully as 'airbnb_cleaned.csv'!")
# Out:
#                  id        host_id  latitude  longitude     price  \
# count     45,237.00      45,237.00 45,237.00  45,237.00 45,237.00
# mean  18,916,395.51  66,505,663.83     40.73     -73.95    119.91
# min        2,539.00       2,571.00     40.50     -74.24      0.00
# 25%    9,457,917.00   7,831,209.00     40.69     -73.98     65.00
# 50%   19,547,068.00  30,445,677.00     40.72     -73.95    100.00
# 75%   28,911,924.00 105,640,471.00     40.76     -73.93    159.00
# max   36,487,245.00 274,321,313.00     40.91     -73.71    334.00
# std   10,906,854.26  77,617,442.25      0.06       0.05     68.13
#
#        minimum_nights  number_of_reviews                    last_review  \
# count       45,237.00          45,237.00                          36495
# mean             5.56              24.14  2018-10-04 11:22:36.843403264
# min              1.00               0.00            2011-03-28 00:00:00
# 25%              1.00               1.00            2018-07-07 00:00:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count listings by room type
room_type_counts = df["room_type"].value_counts()

# Plot
plt.figure(figsize=(8,5))
sns.barplot(x=room_type_counts.index, y=room_type_counts.values, palette="viridis")
plt.xlabel("Room Type")
plt.ylabel("Number of Listings")
plt.title("Distribution of Room Types in NYC Airbnb")
plt.show()
# Out:
# <ipython-input-2-ee64de599cca>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=room_type_counts.index, y=room_type_counts.values, palette="viridis")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a pivot table with counts of room types per neighborhood group
heatmap_data = df.pivot_table(index="neighbourhood_group", columns="room_type", aggfunc="size", fill_value=0)

# Plot the heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(heatmap_data, annot=True, fmt="d", cmap="viridis", linewidths=0.5)

# Labels and title
plt.xlabel("Room Type")
plt.ylabel("Neighbourhood Group")
plt.title("Distribution of Room Types Across NYC Boroughs")
plt.show()
